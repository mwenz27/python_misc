# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
def plot_shear_wave(line_name, path, number_of_layers):
    '''
    this function reads the individual LST files extracts the data into a dataframe
    QC lines, specify the line 
    '''
    file_list = os.listdir(path)
    lst_file = [line for line in file_list if '.LST' in line]
            
    line_f_b = {"line1": [28, 32,'1'],
                "line2": [32, 36,'2'],
                "line3": [33, 37,'3'],
    }
    
    plt.figure(figsize=(10,10), facecolor='white')
    font = {'family': 'arial',
            'color':  'darkred',
            'weight': 'normal',
            'size': 20,
           }
    
    layers = number_of_layers                                          
    first_line = -5 - layers
    processed_path = path + "processed\\"
    
    string_f = line_f_b[line_name][0]
    string_b = line_f_b[line_name][1]
    primary_line = line_f_b[line_name][2]

    for i in range(len(lst_file)):

        line_name = lst_file[i][string_f:string_b]

        x = list()
        with open(f"{path}{lst_file[i]}", 'r') as fin:
            text_file = fin.readlines()
        #extracting relevant location of the data
        for key, line in enumerate(text_file[first_line:-5]):
            #print(key , line.strip())
            new_text_line = line.split()
            x.append(new_text_line)
 
        headers = [['DEPTH', 'INITIAL Vs', 'INVERTED Vs', 'R-M-S E of Vs',   'Vp' , 'DENSITY']]
        
        ## this is convert the strings into floating point numbers
        for i in x:
            z = []
            for j in i:
                z.append(float(j))
            headers.append(z)

        data = pd.DataFrame(headers[1:], columns=headers[0])
    data.head()
        
        
#         plt.plot( data['INITIAL Vs'],data['DEPTH'], label=line_name )
#         plt.ylim(35,0)


#         z = data['DEPTH']
#         shear_wave = data['INITIAL Vs']
#         fig = plt.figure()
#         ax = fig.add_subplot(111, projection='3d')
#         ax.scatter(x, y, z, c=shear_wave, cmap='viridis', linewidth=0.5);

        
        
#     plt.legend(loc=4, title='Station')
#     plt.xlabel("Shear Wave Velocity (m/s)", fontdict=font)
#     plt.ylabel("Depth (m)", fontdict=font)
#     plt.title(f"Line {primary_line}: {number_of_layers} Layers : Depth vs Shear Wave Velocity (Vs)", fontdict=font)

# %%
s1 = "C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW1\\Revision_6\\13_layer_25m_fixed_depth_equal_int\\"
plot_shear_wave('line1',s1, 13)

# %%
x = [i*2 for i in range(10)]
y = [i+3 for i in range(10)]
z = [i**2 for i in range(10)]

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);

# %%
dataset_path = "C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW3\\Line3_Rev4\\20_layer_25m_fixed_depth_equal_init\\processed\\l3_data.txt"

# %%
dataset_path
# Out:
# 'C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW3\\Line3_Rev4\\20_layer_25m_fixed_depth_equal_init\\processed\\l3_data.txt'

# %%
header_list = [["line", "station", "x", "y", "z", "depth", "shearwave"]]
data = pd.read_csv(dataset_path,delimiter="\t")
data.head()
# Out:
#    line  station           x            y elevation  depth  shearwave  \
# 0     3     3001  404748.686  6464790.623     29.46   1.23      337.0
# 1     3     3001  404748.686  6464790.623     29.46   2.45      337.0
# 2     3     3001  404748.686  6464790.623     29.46   3.68      337.0
# 3     3     3001  404748.686  6464790.623     29.46   4.90      337.0
# 4     3     3001  404748.686  6464790.623     29.46   6.13      337.0
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
fig = plt.figure()

ax = fig.add_subplot(111,projection='3d')
ax.scatter(data['x'], data['y'], data['depth'], c=data['shearwave'], cmap='viridis', linewidth=0.5);
# rotate the axes and update

path = "C:\\Users\\Ninja\\Desktop\\plt_image\\"
for angle in range(35, 45):
    ax.view_init(55, angle)
    ax.set_xlabel('Easting')
    ax.set_ylabel('Northing')
    ax.set_zlabel('depth')
    plt.savefig(f'{path}angle{angle}.png')

# %%
plt.contour(data['x'], data['depth'], data['shearwave'], levels=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-694c412cabc4> in <module>
# ----> 1 plt.contour(data['x'], data['depth'], data['shearwave'], levels=12)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in contour(data, *args, **kwargs)
#    2537     __ret = gca().contour(
#    2538         *args, **({"data": data} if data is not None else {}),
# -> 2539         **kwargs)
#    2540     if __ret._A is not None: sci(__ret)  # noqa
#    2541     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
import numpy as np

# %%
x = np.arange(-3.0, 3.0, 0.1)
y = np.arange(-3.0, 3.0, 0.1)

# %%
x
# Out:
# array([-3.00000000e+00, -2.90000000e+00, -2.80000000e+00, -2.70000000e+00,
#        -2.60000000e+00, -2.50000000e+00, -2.40000000e+00, -2.30000000e+00,
#        -2.20000000e+00, -2.10000000e+00, -2.00000000e+00, -1.90000000e+00,
#        -1.80000000e+00, -1.70000000e+00, -1.60000000e+00, -1.50000000e+00,
#        -1.40000000e+00, -1.30000000e+00, -1.20000000e+00, -1.10000000e+00,
#        -1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
#        -2.00000000e-01, -1.00000000e-01,  2.66453526e-15,  1.00000000e-01,
#         2.00000000e-01,  3.00000000e-01,  4.00000000e-01,  5.00000000e-01,
#         6.00000000e-01,  7.00000000e-01,  8.00000000e-01,  9.00000000e-01,
#         1.00000000e+00,  1.10000000e+00,  1.20000000e+00,  1.30000000e+00,
#         1.40000000e+00,  1.50000000e+00,  1.60000000e+00,  1.70000000e+00,
# ...

# %%
X, Y = np.meshgrid(x, y)

# %%
X
# Out:
# array([[-3. , -2.9, -2.8, ...,  2.7,  2.8,  2.9],
#        [-3. , -2.9, -2.8, ...,  2.7,  2.8,  2.9],
#        [-3. , -2.9, -2.8, ...,  2.7,  2.8,  2.9],
#        ...,
#        [-3. , -2.9, -2.8, ...,  2.7,  2.8,  2.9],
#        [-3. , -2.9, -2.8, ...,  2.7,  2.8,  2.9],
#        [-3. , -2.9, -2.8, ...,  2.7,  2.8,  2.9]])

# %%
Y
# Out:
# array([[-3. , -3. , -3. , ..., -3. , -3. , -3. ],
#        [-2.9, -2.9, -2.9, ..., -2.9, -2.9, -2.9],
#        [-2.8, -2.8, -2.8, ..., -2.8, -2.8, -2.8],
#        ...,
#        [ 2.7,  2.7,  2.7, ...,  2.7,  2.7,  2.7],
#        [ 2.8,  2.8,  2.8, ...,  2.8,  2.8,  2.8],
#        [ 2.9,  2.9,  2.9, ...,  2.9,  2.9,  2.9]])

# %%
Z = np.sin(X)*np.cos(Y)

# %%
Z
# Out:
# array([[ 0.13970775,  0.23685504,  0.33163576, ..., -0.42310287,
#         -0.33163576, -0.23685504],
#        [ 0.13702162,  0.23230109,  0.32525948, ..., -0.41496798,
#         -0.32525948, -0.23230109],
#        [ 0.13296642,  0.22542606,  0.31563332, ..., -0.40268687,
#         -0.31563332, -0.22542606],
#        ...,
#        [ 0.12758267,  0.21629865,  0.30285345, ..., -0.38638224,
#         -0.30285345, -0.21629865],
#        [ 0.13296642,  0.22542606,  0.31563332, ..., -0.40268687,
#         -0.31563332, -0.22542606],
#        [ 0.13702162,  0.23230109,  0.32525948, ..., -0.41496798,
#         -0.32525948, -0.23230109]])

# %%
fig, ax = plt.subplots(figsize=(6,6))
ax.contour(X,Y,Z)
plt.show()

# %%
ax.contourf(X, Y, Z)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import Rbf

# %%
dataset_path = "C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW3\\Line3_Rev4\\20_layer_25m_fixed_depth_equal_init\\processed\\l3_data.txt"

# %%
dataset_path
# Out:
# 'C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW3\\Line3_Rev4\\20_layer_25m_fixed_depth_equal_init\\processed\\l3_data.txt'

# %%
header_list = [["line", "station", "x", "y", "z", "depth", "shearwave"]]
data = pd.read_csv(dataset_path,delimiter="\t")
data.head()
# Out:
#    line  station           x            y  elevation  depth  shearwave  \
# 0     3     3001  404748.686  6464790.623      29.46   1.23      337.0
# 1     3     3001  404748.686  6464790.623      29.46   2.45      337.0
# 2     3     3001  404748.686  6464790.623      29.46   3.68      337.0
# 3     3     3001  404748.686  6464790.623      29.46   4.90      337.0
# 4     3     3001  404748.686  6464790.623      29.46   6.13      337.0
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# Build a regular grid with 500-metre cells.
extent = x_min, x_max, y_min, y_max = [data.y.min()-1000, data.y.max()+1000,
                                       data.depth.min()-1000, data.depth.max()+1000]
grid_x, grid_y = np.mgrid[x_min:x_max:500, y_min:y_max:500]

# %%
rbfi = Rbf(data.x, data.y, data.shearwave)
di = rbfi(grid_x, grid_y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-8-2200ed12d1d2> in <module>
# ----> 1 rbfi = Rbf(data.x, data.y, data.shearwave)
#       2 di = rbfi(grid_x, grid_y)
#
# ~\Anaconda3\lib\site-packages\scipy\interpolate\rbf.py in __init__(self, *args, **kwargs)
#     218             setattr(self, item, value)
#     219
# --> 220         self.nodes = linalg.solve(self.A, self.di)
#     221
#     222     @property
#
# ~\Anaconda3\lib\site-packages\scipy\linalg\basic.py in solve(a, b, sym_pos, lower, overwrite_a, overwrite_b, debug, check_finite, assume_a, transposed)
#     214                                                (a1, b1))
#     215         lu, ipvt, info = getrf(a1, overwrite_a=overwrite_a)
# --> 216         _solve_check(n, info)
#     217         x, info = getrs(lu, ipvt, b1,
#     218                         trans=trans, overwrite_b=overwrite_b)
#
# ...
