# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E411-BCD7
#
#  Directory of C:\Users\Ninja\Documents\Python Scripts\python_misc\Plotting_data
#
# 09/08/2019  03:52 PM    <DIR>          .
# 09/08/2019  03:52 PM    <DIR>          ..
# 09/08/2019  03:52 PM    <DIR>          .ipynb_checkpoints
# 09/08/2019  03:52 PM            29,562 DC curve images.ipynb
# 08/08/2019  05:40 PM             2,059 Line1(ActiveOT)(CombinedOT)(1001).DC
# 08/08/2019  06:35 PM               496 Line1.DCT
# 08/08/2019  08:07 AM               604 Line3.DCT
#                4 File(s)         32,721 bytes
#                3 Dir(s)  118,362,386,432 bytes free

# %%
df2 = pd.read_csv("Line3.DCT", header=1, sep=" ", delimiter='\t')
df2
# Out:
#                       ndata 16 1
# DATA  12.056 364.286       0.965
#       12.965 304.464       0.702
#       14.278 274.107       0.888
#       15.025 287.807       0.996
#       15.781 300.137       1.000
#       16.617 308.514       0.951
#       17.546 311.834       1.000
#       18.586 316.223       1.000
#       19.756 313.658       1.000
#       21.084 316.256       0.987
#       22.604 318.614       1.000
#       24.359 320.133       1.000
#       26.243 315.179       1.000
#       28.565 327.679       1.000
#       30.332 324.107       1.000
#       32.452 323.214       0.794
# >>End NaN    NaN             NaN

# %% [markdown]
# the data frame read is not correct, will need to modify it.

# %% [markdown]
# df = pd.read_csv("Line3.DCT", header=1, sep=" ", delimiter='\t')
# df

# %%
df = pd.read_csv("Line3.DCT", header=1, sep=" ", delimiter='\t', names=['data','depth','vs','err'], na_values='>>End')
df
# Out:
#     data   depth       vs    err
# 0   DATA  12.056  364.286  0.965
# 1   DATA  12.965  304.464  0.702
# 2   DATA  14.278  274.107  0.888
# 3   DATA  15.025  287.807  0.996
# 4   DATA  15.781  300.137  1.000
# 5   DATA  16.617  308.514  0.951
# 6   DATA  17.546  311.834  1.000
# 7   DATA  18.586  316.223  1.000
# 8   DATA  19.756  313.658  1.000
# 9   DATA  21.084  316.256  0.987
# 10  DATA  22.604  318.614  1.000
# 11  DATA  24.359  320.133  1.000
# 12  DATA  26.243  315.179  1.000
# 13  DATA  28.565  327.679  1.000
# 14  DATA  30.332  324.107  1.000
# 15  DATA  32.452  323.214  0.794
# 16   NaN     NaN      NaN    NaN

# %%
df.columns
# Out:
# Index(['data', 'depth', 'vs', 'err'], dtype='object')

# %%
for i in df.columns:
    print(i)
# Out:
# data
# depth
# vs
# err

# %%
min(df['12.056000'])
# Out:
# 12.965

# %%
plt.plot( df['vs'], df['depth'], marker='o')
plt.ylim(max(df['depth'])+5, min(df['depth'])-5)
plt.xlabel("Shear Velocity")
plt.ylabel("Depth")
plt.title("Depth vs Shear Velocity")
# Out:
# Text(0.5, 1.0, 'Depth vs Shear Velocity')

# %%
lines = ['Line1.DCT', 'Line3.DCT']
for line in lines:
    df = pd.read_csv(line, header=1, delimiter='\t', names=['data','depth','vs','err'], na_values='>>End')
    string = line.strip('.DCT')
    plt.plot( df['vs'], df['depth'], marker='o', label=string)
    plt.ylim(max(df['depth'])+5, min(df['depth'])-5)
    plt.xlabel("Shear Velocity")
    plt.ylabel("Depth")
    plt.title("Shear Velocity vs Depth")
    plt.legend(loc=3)

# %%
import os
arr = os.listdir('data')
# Out:
# ['Line1(ActiveOT)(CombinedOT)(1001).DCT', 'Line1(ActiveOT)(CombinedOT)(1002).DCT', 'Line1(ActiveOT)(CombinedOT)(1003).DCT', 'Line1(ActiveOT)(CombinedOT)(1004).DCT', 'Line1(ActiveOT)(CombinedOT)(1005).DCT', 'Line1(ActiveOT)(CombinedOT)(1006).DCT', 'Line1(ActiveOT)(CombinedOT)(1007).DCT', 'Line1(ActiveOT)(CombinedOT)(1008).DCT', 'Line1(ActiveOT)(CombinedOT)(1009).DCT', 'Line1(ActiveOT)(CombinedOT)(1010).DCT', 'Line1(ActiveOT)(CombinedOT)(1011).DCT', 'Line1(ActiveOT)(CombinedOT)(1012).DCT', 'Line1(ActiveOT)(CombinedOT)(1013).DCT', 'Line1(ActiveOT)(CombinedOT)(1014).DCT', 'Line1(ActiveOT)(CombinedOT)(1015).DCT', 'Line1(ActiveOT)(CombinedOT)(1016).DCT', 'Line1(ActiveOT)(CombinedOT)(1017).DCT', 'Line1(ActiveOT)(CombinedOT)(1018).DCT', 'Line1(ActiveOT)(CombinedOT)(1019).DCT', 'Line1(ActiveOT)(CombinedOT)(1020).DCT', 'Line1(ActiveOT)(CombinedOT)(1021).DCT', 'Line1(ActiveOT)(CombinedOT)(1022).DCT', 'Line1(ActiveOT)(CombinedOT)(1023).DCT', 'Line1(ActiveOT)(CombinedOT)(1024).DCT', 'Line1(ActiveOT)(CombinedOT)(1025).DCT', 'Line1(ActiveOT)(CombinedOT)(1026).DCT', 'Line1(ActiveOT)(CombinedOT)(1027).DCT', 'Line1(ActiveOT)(CombinedOT)(1028).DCT', 'Line1(ActiveOT)(CombinedOT)(1029).DCT', 'Line1(ActiveOT)(CombinedOT)(1030).DCT', 'Line1(ActiveOT)(CombinedOT)(1031).DCT']

# %% [markdown]
# ### Test dataset

# %%
plt.figure(figsize=(20,10))
count = 0
for line in arr:
    df = pd.read_csv(f'data\\{line}', header=1, delimiter='\t', names=['data','depth','vs','err'], na_values='>>End')
    string = line.rstrip(').DCT').lstrip('Line1(ActiveOT)(CombinedOT)(')
    count += 1
    if count <= 10:
        plt.plot( df['vs'], df['depth'], label=string, color='696885')
    elif 10 < count <= 20:
        plt.plot( df['vs'], df['depth'], label=string, color='#514F95')
    elif count > 20:
        plt.plot( df['vs'], df['depth'], label=string, color='#57B886')
    plt.ylim(max(df['depth'])+5, min(df['depth'])-5)
    plt.ylim(30,6)
    plt.xlabel("Shear Velocity")
    plt.ylabel("Depth")
    plt.title("Shear Velocity vs Depth")
    plt.legend(loc=4)

# %% [markdown]
# ## Line 2

# %%
line2_path = 'C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW2\\revision_3\\10_layer_25m_updated_12thpick\\'

# %%
line2 = os.listdir(line2_path)

# %%
line2 = [line for line in line2 if '.DCT' in line]

# %%
line2
# Out:
# ['Line2(ActiveOT_LOW)(CombinedOT)(2001).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2002).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2003).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2004).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2005).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2006).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2007).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2008).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2009).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2010).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2011).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2012).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2013).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2014).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2015).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2016).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2017).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2018).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2019).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2020).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2021).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2022).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2023).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2024).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2025).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2026).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2027).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2028).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2029).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2030).DCT',
#  'Line2(ActiveOT_LOW)(CombinedOT)(2031).DCT']

# %%
(list(range(0,5,1)))
# Out:
# [0, 1, 2, 3, 4]

# %%
x = lambda x : str(x)

# %%
range_list2 = [line for line in line2 if x(list(range(2021,2032, 1))) in line]

# %%
range_list2
# Out:
# []

# %%
# plt.figure(figsize=(20,40))
count = 0
for line in line2:
    df = pd.read_csv(f'{line2_path}{line}', header=1, delimiter='\t', names=['data','depth','vs','err'], na_values='>>End')
    string = line.rstrip(').DCT').lstrip('Line2(ActiveOT_LOW)(CombinedOT)(')
    count += 1
    if count <= 10:
        plt.plot( df['vs'], df['depth'], label=string, color='696885')
    elif 10 < count <= 20:
        plt.plot( df['vs'], df['depth'], label=string, color='#514F95')
    elif count > 20:
        plt.plot( df['vs'], df['depth'], label=string, color='#57B886')
#     plt.ylim(max(df['depth'])+5, min(df['depth'])-5)
    plt.ylim(max(df['depth'])+5, min(df['depth'])-5)
    plt.ylim(35,5)
    plt.xlabel("Shear Velocity")
    plt.ylabel("Depth")
    plt.title("LINE 2 ---------- Shear Velocity vs Depth ------------------")
    plt.legend(loc=4)

# %% [markdown]
# ## Line 3

# %%
line3_path = 'C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW3\\Line3_Revision2\\revision_10_layer_25m\\'

# %%
line3 = os.listdir(line3_path)

# %%
line3 = [line for line in line3 if '.DCT' in line]

# %%
line3
# Out:
# ['Line3_LOW_(ActiveOT)(CombinedOT)(3001).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3002).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3003).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3004).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3005).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3006).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3007).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3008).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3009).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3010).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3011).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3012).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3013).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3014).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3015).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3016).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3017).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3018).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3019).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3020).DCT',
#  'Line3_LOW_(ActiveOT)(CombinedOT)(3021).DCT']

# %%
plt.figure(figsize=(20,20), facecolor='white')
font = {'family': 'arial',
        'color':  'darkred',
        'weight': 'normal',
        'size': 20,
        }
count = 0
for line in line3:
    df = pd.read_csv(f'{line3_path}{line}', header=1, delimiter='\t', names=['data','depth','vs','err'], na_values='>>End')
    string = line.rstrip(').DCT').lstrip('Line3_LOW_(ActiveOT)(CombinedOT)(')
    count += 1
    if count <= 7:
        plt.plot( df['vs'], df['depth'], label=string, color='696885')
    elif 7 < count <= 14:
        plt.plot( df['vs'], df['depth'], label=string, color='#514F95')
    elif count > 14:
        plt.plot( df['vs'], df['depth'], label=string, color='#57B886')
#     plt.ylim(max(df['depth'])+5, min(df['depth'])-5)
    plt.ylim(35,8)
    plt.xlabel("Shear Velocity", fontdict=font)
    plt.ylabel("Depth", fontdict=font)
    plt.title("LINE 3 ---------- Shear Velocity vs Depth ------------------", fontdict=font)
    plt.legend(loc=4, title='Shot Point')
#     plt.grid(axis='both', color='r',  linestyle='--', linewidth=1, markerfacecoloralt='b')
 
# plt.savefig('line3_image.png')

# %%
import seaborn as sns
sns.set()

# %%
one_line = f'{line3_path}{line3[1]}'
one_line
# Out:
# 'C:\\Users\\Ninja\\Documents\\MASW\\Dundass_Road_MASW\\Dundass_Road_MASW\\SG2\\MASW3\\Line3_Revision2\\revision_10_layer_25m\\Line3_LOW_(ActiveOT)(CombinedOT)(3002).DCT'

# %%
one_line_df = pd.read_csv(one_line, header=1, delimiter='\t', names=['data','depth','vs','err'], na_values='>>End')

# %%
one_line_df.head()
# Out:
#    data   depth       vs    err
# 0  DATA  12.258  388.393  0.990
# 1  DATA  12.612  349.107  0.919
# 2  DATA  13.470  324.107  0.985
# 3  DATA  14.177  330.357  0.954
# 4  DATA  15.136  324.107  1.000

# %%
plt.hist(one_line_df['vs'])
# Out:
# C:\Users\Ninja\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Ninja\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([1., 7., 6., 1., 1., 1., 2., 0., 0., 1.]),
#  array([312.5   , 320.0893, 327.6786, 335.2679, 342.8572, 350.4465,
#         358.0358, 365.6251, 373.2144, 380.8037, 388.393 ]),
#  <a list of 10 Patch objects>)

# %%
one_line_df.std
# Out:
# <bound method DataFrame.std of     data   depth       vs    err
# 0   DATA  12.258  388.393  0.990
# 1   DATA  12.612  349.107  0.919
# 2   DATA  13.470  324.107  0.985
# 3   DATA  14.177  330.357  0.954
# 4   DATA  15.136  324.107  1.000
# 5   DATA  15.811  329.248  0.975
# 6   DATA  16.580  329.055  1.000
# 7   DATA  17.428  328.902  1.000
# 8   DATA  18.367  325.019  1.000
# 9   DATA  19.413  325.082  0.972
# 10  DATA  20.586  332.338  0.970
# 11  DATA  21.043  350.893  1.000
# 12  DATA  21.750  333.929  0.775
# 13  DATA  22.911  360.714  0.751
# 14  DATA  23.769  364.286  1.000
# 15  DATA  25.183  324.107  1.000
# 16  DATA  27.101  320.536  1.000
# 17  DATA  28.161  312.500  1.000
# 18  DATA  29.575  323.214  1.000
# 19  DATA  30.837  342.857  0.844
# 20   NaN     NaN      NaN    NaN>
