# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E411-BCD7
#
#  Directory of C:\Users\Ninja\Documents\Python Scripts\python_misc\Plotting_data
#
# 27/08/2019  11:49 AM    <DIR>          .
# 27/08/2019  11:49 AM    <DIR>          ..
# 27/08/2019  11:49 AM    <DIR>          .ipynb_checkpoints
# 26/08/2019  12:10 PM           249,253 3d plotting.ipynb
# 18/08/2019  01:40 PM            11,265 Crosshole_data_qc_check.ipynb
# 26/08/2019  07:34 AM            23,694 Cross_hole_file_conversion.ipynb
# 27/08/2019  11:53 AM    <DIR>          data
# 12/08/2019  01:44 PM         1,098,079 DC curve images.ipynb
# 11/08/2019  04:59 PM           287,869 Graphs.ipynb
# 08/08/2019  05:40 PM             2,059 Line1(ActiveOT)(CombinedOT)(1001).DC
# 08/08/2019  06:35 PM               496 Line1.DCT
# 08/08/2019  08:07 AM               604 Line3.DCT
# 11/08/2019  08:35 AM           295,666 line3_image.png
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("data/track.csv")

# %%
len(df)
# Out:
# 740

# %%
df.columns
# Out:
# Index(['time', 'lat', 'lng', 'height'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 4 columns):
# time      740 non-null object
# lat       740 non-null float64
# lng       740 non-null float64
# height    740 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 23.2+ KB

# %%
df.dtypes
# Out:
# time       object
# lat       float64
# lng       float64
# height    float64
# dtype: object

# %%
df['lat']
# Out:
# 0      35.015021
# 1      35.014954
# 2      35.014871
# 3      35.014824
# 4      35.014776
# 5      35.014704
# 6      35.014657
# 7      35.014563
# 8      35.014549
# 9      35.014515
# 10     35.014505
# 11     35.014481
# 12     35.014472
# 13     35.014439
# 14     35.014432
# 15     35.014414
# 16     35.014400
# 17     35.014372
# 18     35.014365
# 19     35.014337
# 20     35.014331
# 21     35.014303
# 22     35.014306
# 23     35.014340
# 24     35.013531
# 25     35.013606
# 26     35.013630
# 27     35.013705
# 28     35.013730
# 29     35.013809
#          ...
# 710    35.015705
# 711    35.015640
# 712    35.015617
# 713    35.015551
# 714    35.015533
# 715    35.015468
# 716    35.015444
# 717    35.015369
# 718    35.015343
# 719    35.015264
# 720    35.015238
# 721    35.015157
# 722    35.015129
# 723    35.015048
# 724    35.015023
# 725    35.014943
# 726    35.014916
# 727    35.014835
# 728    35.014810
# 729    35.014737
# 730    35.014709
# ...

# %%
df[['lat', 'lng']]
# Out:
#            lat        lng
# 0    35.015021  32.519585
# 1    35.014954  32.519606
# 2    35.014871  32.519612
# 3    35.014824  32.519654
# 4    35.014776  32.519689
# 5    35.014704  32.519691
# 6    35.014657  32.519734
# 7    35.014563  32.519719
# 8    35.014549  32.519694
# 9    35.014515  32.519625
# 10   35.014505  32.519599
# 11   35.014481  32.519514
# 12   35.014472  32.519486
# 13   35.014439  32.519405
# 14   35.014432  32.519379
# 15   35.014414  32.519309
# 16   35.014400  32.519287
# 17   35.014372  32.519211
# 18   35.014365  32.519187
# 19   35.014337  32.519106
# 20   35.014331  32.519084
# 21   35.014303  32.519009
# 22   35.014306  32.518989
# 23   35.014340  32.518916
# 24   35.013531  32.517636
# 25   35.013606  32.517589
# 26   35.013630  32.517574
# 27   35.013705  32.517529
# 28   35.013730  32.517512
# 29   35.013809  32.517459
# ..         ...        ...
# 710  35.015705  32.516157
# 711  35.015640  32.516211
# 712  35.015617  32.516225
# ...

# %%
df.loc[0]
# Out:
# time      2015-08-20 03:48:07.235
# lat                        35.015
# lng                       32.5196
# height                      136.2
# Name: 0, dtype: object

# %%
df.loc[2:7]
# Out:
#                       time        lat        lng      height
# 2  2015-08-20 03:48:25.660  35.014871  32.519612  123.000000
# 3  2015-08-20 03:48:26.819  35.014824  32.519654  120.500000
# 4  2015-08-20 03:48:27.828  35.014776  32.519689  118.900002
# 5  2015-08-20 03:48:29.720  35.014704  32.519691  119.900002
# 6  2015-08-20 03:48:30.669  35.014657  32.519734  120.900002
# 7  2015-08-20 03:48:33.793  35.014563  32.519719  121.699997

# %%
df.index
# Out:
# RangeIndex(start=0, stop=740, step=1)

# %%
import numpy as np
df1 = pd.DataFrame(np.arange(10).reshape((5,2)), columns=["x","y"], index=['a','b','c', 'd','e'])
df1
# Out:
#    x  y
# a  0  1
# b  2  3
# c  4  5
# d  6  7
# e  8  9

# %%
df1.loc['a']
# Out:
# x    0
# y    1
# Name: a, dtype: int32

# %%
df1.loc['b':'d']
# Out:
#    x  y
# b  2  3
# c  4  5
# d  6  7

# %%
df.index
# Out:
# RangeIndex(start=0, stop=740, step=1)
